# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from google.colab.patches import cv2_imshow

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Reading a colour image, if it is, as a grayscale
# The quest behind this is to simplify the ananlysis
# It removes the alpha, which is just degree of opaqueness
img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/MLFA/Lab 2/lena_grayscale.png', cv2.IMREAD_GRAYSCALE)

# img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/MLFA/Lab 2/lena_grayscale.png',cv2.IMREAD_COLOR)
# img = cv2.imread('/content/drive/MyDrive/Colab Notebooks/MLFA/Lab 2/lena_grayscale.png',cv2.IMREAD_UNCHANGED)

#IMREAD_COLOR = 1
#IMREAD_GRAYSCALE = 0
#IMREAD_UNCHANGED = -1

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=L size=256x256 at 0x7FF3A0FD3E50>

# %%
plt.imshow(img, cmap = 'gray', interpolation = 'bicubic')
plt.plot([50, 100], [80, 100], 'c', linewidth = 5)
plt.show()

# %%
# Saving an image
cv2.imwrite('lenagray.png', img)
# Out:
# True
